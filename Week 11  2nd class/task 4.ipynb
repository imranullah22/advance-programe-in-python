# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('population2020.csv')
data
# Out:
#               Country  Population Yearly Change  Net Change  Density  \
# 0               China  1440297825        0.39 %     5540090      153
# 1               India  1382345085        0.99 %    13586631      464
# 2       United States   331341050        0.59 %     1937734       36
# 3           Indonesia   274021604        1.07 %     2898047      151
# 4            Pakistan   221612785        2.00 %     4327022      287
# ..                ...         ...           ...         ...      ...
# 230        Montserrat        4993        0.06 %           3       50
# 231  Falkland Islands        3497        3.05 %         103        0
# 232              Niue        1628        0.68 %          11        6
# 233           Tokelau        1360        1.27 %          17      136
# 234          Holy See         801        0.25 %           2     2003
#
#      Land Area  Migrants Fert. Rate Med. Age Urban Pop World Share
# 0      9388211 -348399.0        1.7       38      61 %     18.47 %
# ...

# %%
data.set_index('Country', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-6372a9bee8e4> in <module>
# ----> 1 data.set_index('Country', inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
data
# Out:
#                   Population Yearly Change  Net Change  Density  Land Area  \
# Country
# China             1440297825        0.39 %     5540090      153    9388211
# India             1382345085        0.99 %    13586631      464    2973190
# United States      331341050        0.59 %     1937734       36    9147420
# Indonesia          274021604        1.07 %     2898047      151    1811570
# Pakistan           221612785        2.00 %     4327022      287     770880
# ...                      ...           ...         ...      ...        ...
# Montserrat              4993        0.06 %           3       50        100
# Falkland Islands        3497        3.05 %         103        0      12170
# Niue                    1628        0.68 %          11        6        260
# Tokelau                 1360        1.27 %          17      136         10
# Holy See                 801        0.25 %           2     2003          0
#
# ...

# %%
data.isnull()
# Out:
#      Country  Population  Yearly Change  Net Change  Density  Land Area  \
# 0      False       False          False       False    False      False
# 1      False       False          False       False    False      False
# 2      False       False          False       False    False      False
# 3      False       False          False       False    False      False
# 4      False       False          False       False    False      False
# ..       ...         ...            ...         ...      ...        ...
# 230    False       False          False       False    False      False
# 231    False       False          False       False    False      False
# 232    False       False          False       False    False      False
# 233    False       False          False       False    False      False
# 234    False       False          False       False    False      False
#
#      Migrants  Fert. Rate  Med. Age  Urban Pop  World Share
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#                  Country  Population Yearly Change  Net Change  Density  \
# 0                  China  1440297825        0.39 %     5540090      153
# 1                  India  1382345085        0.99 %    13586631      464
# 2          United States   331341050        0.59 %     1937734       36
# 3              Indonesia   274021604        1.07 %     2898047      151
# 4               Pakistan   221612785        2.00 %     4327022      287
# ..                   ...         ...           ...         ...      ...
# 196                Aruba      106845        0.43 %         452      593
# 197                Tonga      105901        1.15 %        1201      147
# 198  U.S. Virgin Islands      104398       -0.15 %        -153      298
# 199           Seychelles       98453        0.62 %         608      214
# 200  Antigua and Barbuda       98069        0.84 %         811      223
#
#      Land Area  Migrants Fert. Rate Med. Age Urban Pop World Share
# ...

# %%
top3 = data.nlargest(3, ['Population'])

# %%
top3
# Out:
#          Country  Population Yearly Change  Net Change  Density  Land Area  \
# 0          China  1440297825        0.39 %     5540090      153    9388211
# 1          India  1382345085        0.99 %    13586631      464    2973190
# 2  United States   331341050        0.59 %     1937734       36    9147420
#
#    Migrants Fert. Rate Med. Age Urban Pop World Share
# 0 -348399.0        1.7       38      61 %     18.47 %
# 1 -532687.0        2.2       28      35 %     17.70 %
# 2  954806.0        1.8       38      83 %      4.25 %

# %%
plt.pie(top3['Population'].values, labels=top3['Country'].values)
plt.show()

# %%
plt.pie(data.nsmallest(3, ['Population'])['Population'].values, labels=data.nsmallest(3, ['Population'])['Country'].values)
plt.show()
