# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
table = pd.read_csv("population2020.csv")
table
# Out:
#               Country  Population Yearly Change  Net Change  Density (P/Km²)  \
# 0               China  1440297825         0.39%     5540090              153
# 1               India  1382345085         0.99%    13586631              464
# 2       United States   331341050         0.59%     1937734               36
# 3           Indonesia   274021604         1.07%     2898047              151
# 4            Pakistan   221612785         2.00%     4327022              287
# ..                ...         ...           ...         ...              ...
# 230        Montserrat        4993         0.06%           3               50
# 231  Falkland Islands        3497         3.05%         103                0
# 232              Niue        1628         0.68%          11                6
# 233           Tokelau        1360         1.27%          17              136
# 234          Holy See         801         0.25%           2             2003
#
# ...

# %%
print("Total Null values count: ",
      table.isnull().sum().sum())
# Out:
# Total Null values count:  34

# %%
drop=table.dropna()
drop
# Out:
#                  Country  Population Yearly Change  Net Change  \
# 0                  China  1440297825         0.39%     5540090
# 1                  India  1382345085         0.99%    13586631
# 2          United States   331341050         0.59%     1937734
# 3              Indonesia   274021604         1.07%     2898047
# 4               Pakistan   221612785         2.00%     4327022
# ..                   ...         ...           ...         ...
# 196                Aruba      106845         0.43%         452
# 197                Tonga      105901         1.15%        1201
# 198  U.S. Virgin Islands      104398        -0.15%        -153
# 199           Seychelles       98453         0.62%         608
# 200  Antigua and Barbuda       98069         0.84%         811
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211       -348399.0        1.7       38
# ...

# %%
drop.isnull().sum()
# Out:
# Country            0
# Population         0
# Yearly Change      0
# Net Change         0
# Density (P/Km²)    0
# Land Area (Km²)    0
# Migrants (net)     0
# Fert. Rate         0
# Med. Age           0
# Urban Pop %        0
# World Share        0
# dtype: int64

# %%
lg=table.Population.nlargest(3)
lg
# Out:
# 0    1440297825
# 1    1382345085
# 2     331341050
# Name: Population, dtype: int64

# %%
table[['Country','Population']]
# Out:
#               Country  Population
# 0               China  1440297825
# 1               India  1382345085
# 2       United States   331341050
# 3           Indonesia   274021604
# 4            Pakistan   221612785
# ..                ...         ...
# 230        Montserrat        4993
# 231  Falkland Islands        3497
# 232              Niue        1628
# 233           Tokelau        1360
# 234          Holy See         801
#
# [235 rows x 2 columns]

# %%
table.nlargest(3,'Population')
# Out:
#          Country  Population Yearly Change  Net Change  Density (P/Km²)  \
# 0          China  1440297825         0.39%     5540090              153
# 1          India  1382345085         0.99%    13586631              464
# 2  United States   331341050         0.59%     1937734               36
#
#    Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop % World Share
# 0          9388211       -348399.0        1.7       38         61%      18.47%
# 1          2973190       -532687.0        2.2       28         35%      17.70%
# 2          9147420        954806.0        1.8       38         83%       4.25%

# %%
plt.style.use("ggplot")
plt.figure(figsize=[9,7])
table.nlargest(3,'Population').value_counts().plot.pie()
plt.show()

# %%
table.nsmallest(3,'Population')
# Out:
#       Country  Population Yearly Change  Net Change  Density (P/Km²)  \
# 234  Holy See         801         0.25%           2             2003
# 233   Tokelau        1360         1.27%          17              136
# 232      Niue        1628         0.68%          11                6
#
#      Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop %  \
# 234                0             NaN       N.A.     N.A.        N.A.
# 233               10             NaN       N.A.     N.A.          0%
# 232              260             NaN       N.A.     N.A.         46%
#
#     World Share
# 234       0.00%
# 233       0.00%
# 232       0.00%

# %%
S=np.array([801,1360,1628])
Country=['Holy See','Tokelau','Niue']
plt.pie(S,labels=Country)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
